# %%
! pip install bnlp_toolkit
! pip install banglanltk
! pip install inltk
! pip install bnltk
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 22.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.1/53.1 kB 5.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 175.4/175.4 kB 21.6 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 993.5/993.5 kB 58.1 MB/s eta 0:00:00
# ...
#   Created wheel for emoji: filename=emoji-1.7.0-py3-none-any.whl size=171033 sha256=048f77042201cb58cd9e5bd5928ec52806a7066e1150ce90a3b10cacdc632895
#   Stored in directory: /root/.cache/pip/wheels/31/8a/8c/315c9e5d7773f74b33d5ed33f075b49c6eaeb7cedbb86e2cf8
# Successfully built emoji
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 462.3/462.3 kB 8.1 MB/s eta 0:00:00
# ...

# %%
! pip install transformers
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.2/7.2 MB 34.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 236.8/236.8 kB 23.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 90.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 54.8 MB/s eta 0:00:00
# ...

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from bs4 import BeautifulSoup
import re
from wordcloud import WordCloud
import string

from wordcloud import WordCloud
import matplotlib.pylab as plt
from PIL import Image, ImageTk
from wordcloud.wordcloud import STOPWORDS
stopwords=set(STOPWORDS)
from collections import Counter
from PIL import Image, ImageDraw, ImageFont
from tensorflow.keras.layers import Embedding,SpatialDropout1D
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.models import Sequential
from tensorflow.keras.preprocessing.text import one_hot
from tensorflow.keras.layers import LSTM
from tensorflow.keras.layers import Dense
import torch
from transformers import BertTokenizer, TFBertModel, BertConfig,TFDistilBertModel
from bnlp.corpus import stopwords, punctuations, letters, digits
from sklearn.metrics import accuracy_score
import tensorflow as tf
import tensorflow_hub as hub
import pandas as pd
from sklearn.model_selection import train_test_split
import numpy as np
import re
import unicodedata
import nltk
from nltk.corpus import stopwords
from tensorflow import keras
from tensorflow.keras.layers import Dense,Dropout, Input
from tqdm import tqdm
import pickle
from sklearn.metrics import confusion_matrix,f1_score,classification_report
import matplotlib.pyplot as plt
import itertools
from sklearn.utils import shuffle
from tensorflow.keras import regularizers
from bs4 import BeautifulSoup
import re

from bnlp.corpus import stopwords, punctuations, letters, digits
from bnlp.corpus import stopwords
from bnlp.corpus.util import remove_stopwords


import banglanltk as bn
from transformers import DistilBertTokenizer, TFDistilBertModel
from matplotlib import font_manager
import pandas as pd
import numpy as np

from sklearn import preprocessing
from sklearn.feature_extraction.text  import CountVectorizer
from sklearn.model_selection import train_test_split

from sklearn.naive_bayes import MultinomialNB

from sklearn import metrics
from transformers import DistilBertTokenizer, DistilBertForMaskedLM
import seaborn as sn
from tensorflow.keras.layers import Dense, GRU, Embedding
import warnings
warnings.simplefilter('ignore')
import numpy as np
import pandas as pd
from tqdm import tqdm
from sklearn import metrics
import transformers
import torch
from torch.utils.data import Dataset, DataLoader, RandomSampler, SequentialSampler
from transformers import DistilBertTokenizer, DistilBertModel
import logging
logging.basicConfig(level=logging.ERROR)
from nltk.tokenize import word_tokenize
from nltk import FreqDist
# %matplotlib inline
# Out:
# punkt not found. downloading...
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.

# %%
df= pd.read_excel("/content/drive/MyDrive/L4/CSE 404/bangla_essay_plagiarism_dataset.xlsx")
df.head()
# Out:
#                       name                                              essay
# 0                অধ্যবসায়  ভূমিকা:\n\nপ্রতিটি মানুষই চায় তার স্বপ্নপূরণে...
# 1  রোকেয়া সাখাওয়াত হোসেন  ভূমিকা: রোকেয়া সাখাওয়াত হোসেনকে বলা হয় বাংল...
# 2             ভাষা আন্দোলন  ভূমিকা: ১৯৪৭ সালে দেশবিভাগের পর থেকে বাংলাকে র...
# 3   বাংলাদেশের মুক্তিযুদ্ধ  ভূমিকা: মুক্তিযুদ্ধ বাংলাদেশের ইতিহাসের সবচেয়...
# 4           সময়ানুবর্তিতা  ভূমিকা: ঠিক সময়ে ঠিক কাজটি করাই সময়ানুবর্তিত...

# %%
from bnlp.corpus import stopwords, punctuations, letters, digits
print(stopwords)
print(punctuations)
print(letters)
print(digits)
# Out:
# ['অতএব', 'অথচ', 'অথবা', 'অনুযায়ী', 'অনেক', 'অনেকে', 'অনেকেই', 'অন্তত', 'অন্য', 'অবধি', 'অবশ্য', 'অর্থাত', 'আই', 'আগামী', 'আগে', 'আগেই', 'আছে', 'আজ', 'আদ্যভাগে', 'আপনার', 'আপনি', 'আবার', 'আমরা', 'আমাকে', 'আমাদের', 'আমার', 'আমি', 'আর', 'আরও', 'ই', 'ইত্যাদি', 'ইহা', 'উচিত', 'উত্তর', 'উনি', 'উপর', 'উপরে', 'এ', 'এঁদের', 'এঁরা', 'এই', 'একই', 'একটি', 'একবার', 'একে', 'এক্', 'এখন', 'এখনও', 'এখানে', 'এখানেই', 'এটা', 'এটাই', 'এটি', 'এত', 'এতটাই', 'এতে', 'এদের', 'এব', 'এবং', 'এবার', 'এমন', 'এমনকী', 'এমনি', 'এর', 'এরা', 'এল', 'এস', 'এসে', 'ঐ', 'ও', 'ওঁদের', 'ওঁর', 'ওঁরা', 'ওই', 'ওকে', 'ওখানে', 'ওদের', 'ওর', 'ওরা', 'কখনও', 'কত', 'কবে', 'কমনে', 'কয়েক', 'কয়েকটি', 'করছে', 'করছেন', 'করতে', 'করবে', 'করবেন', 'করলে', 'করলেন', 'করা', 'করাই', 'করায়', 'করার', 'করি', 'করিতে', 'করিয়া', 'করিয়ে', 'করে', 'করেই', 'করেছিলেন', 'করেছে', 'করেছেন', 'করেন', 'কাউকে', 'কাছ', 'কাছে', 'কাজ', 'কাজে', 'কারও', 'কারণ', 'কি', 'কিংবা', 'কিছু', 'কিছুই', 'কিন্তু', 'কী', 'কে', 'কেউ', 'কেউই', 'কেখা', 'কেন', 'কোটি', 'কোন', 'কোন
# ...

# %%
def remove_punctuation(text):
    punctuation = string.punctuation+ '।' + '-' + '’' + '”' + '“' + '৷'+ '—' + '॥' + '‘' + '–' # Include Bengali sentence-ending punctuation
    text = ''.join([c for c in text if c not in punctuation])
    return text
def remove_extra_whitespace_tabs(text):
   pattern = r'^\s*|\s\s*'
   return re.sub(pattern, ' ', text).strip()

def remove_bn_stopwords(text):
    final_text = []
    text = remove_stopwords(text, stopwords)

    for word in text:
      text = remove_stopwords(word, stopwords)
      final_text.append(word)
    return " ".join(final_text)

# %%
def cleaning(text):
    # print(text)
    text = remove_bn_stopwords(text)
    text = remove_punctuation(text)
    text = remove_extra_whitespace_tabs(text)
    #print(text)
    return text

# %%
import numpy as np

for index, row in df.iterrows():
    essay = row['essay']

    # Check if the essay is a float value
    if isinstance(essay, float):
        print(df['name'][index])
        print(index)
        continue  # Skip this iteration if the essay is a float

    # Split the essay into lines
    lines = essay.splitlines()

    # Process each line as needed
    processed_lines = []
    for line in lines:
        # Perform your desired changes on each line
        processed_line = cleaning(line)
        processed_lines.append(processed_line)

    # Join the processed lines back into an essay
    processed_essay = '\n'.join(processed_lines)

    # Update the df column with the processed essay
    df.at[index, 'essay'] = processed_essay

# %%
df.head()
# Out:
#                       name                                              essay
# 0                অধ্যবসায়  ভূমিকা\n\nপ্রতিটি মানুষই স্বপ্নপূরণের পথে সফল ...
# 1  রোকেয়া সাখাওয়াত হোসেন  ভূমিকা রোকেয়া সাখাওয়াত হোসেনকে বাংলার নারী জ...
# 2             ভাষা আন্দোলন  ভূমিকা ১৯৪৭ সালে দেশবিভাগের বাংলাকে রাষ্ট্রভাষ...
# 3   বাংলাদেশের মুক্তিযুদ্ধ  ভূমিকা মুক্তিযুদ্ধ বাংলাদেশের ইতিহাসের সবচেয়ে...
# 4           সময়ানুবর্তিতা  ভূমিকা সময়ে কাজটি সময়ানুবর্তিতা জীবনে সফলতা ...

# %%
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.metrics.pairwise import cosine_similarity

def check_plagiarism(document1):
    cv = CountVectorizer()
    document_vectors = cv.fit_transform([document1])
    document_vectors = document_vectors.toarray()
    count=0
    for row in df['essay']:
        row_vectors = cv.transform([row])
        row_vectors = row_vectors.toarray()
        cosine_sim = cosine_similarity(row_vectors, document_vectors)

        # print(cosine_sim)
        # print(df['name'][count])

        if cosine_sim > 0.75:
          print(cosine_sim)
          print(df['name'][count])
          print("Plagiarism Detected")
          return 1

        count=count+1
    return 0

# %%
# df

# %%
#document1 = "ভূমিকা: মানুষ ভ্রমণ করতে পছন্দ করে। এই পছন্দকে কাজে লাগিয়ে ভ্রমণ-বান্ধব এক ধরনের ব্যবস্থা গড়ে উঠেছে, যার নাম পর্যটন শিল্প। এই শিল্পের কাজ হলো কোনো অঞ্চলের দর্শনীয় স্থানগুলোর তথ্য ভ্রমণপিপাসু মানুষের কাছে তুলে ধরা, ভ্রমণের সুবন্দোবস্ত করা, এবং এর মাধ্যমে অর্থ উপার্জন করা। বাংলাদেশের একাধিক বনাঞ্চল, পাহাড়-নদী-ঝরনা, শস্যশোভিত মাঠ ও সবুজ প্রকৃতি, বিশ্বের দীর্ঘতম সমুদ্র-সৈকত, নান্দনিক স্থাপত্য ও ভাস্কর্য, প্রত্নতাত্ত্বিক স্থাপনা ও নিদর্শন প্রভৃতি দেশ-বিদেশের পর্যটকদের আকর্ষণ করে । তাই বাংলাদেশে পর্যটন শিল্পের সম্ভাবনা প্রচুর। এগুলোর টানে বিপুল সংখ্যক বিদেশি পর্যটকের বাংলাদেশে আসার সুযোগ রয়েছে। এভাবে বাংলাদেশ পর্যাপ্ত বৈদেশিক মুদ্রা অর্জন করতে পারে। এটি বাংলাদেশের অর্থনীতিতেও গুরুত্বপূর্ণ ভূমিকা রাখতে পারে। প্রথমে বাংলাদেশের গুরুত্বপূর্ণ পর্যটন-কেন্দ্রসমূহের দিকে তাকানো যাক । সুন্দরবন: বাংলাদেশের উপকূলবর্তী অঞ্চলে ৬ হাজার বর্গকিলোমিটারের অধিক জায়গা জুড়ে সুন্দরবন অব
ির উচ্চ শিখরে আরােহণ করেছেন তাঁদের সফলতার পেছনে অধ্যবসায় বড় ভূমিকা পালন করেছে । ১৮শ শতাব্দীর মধ্যভাগ নাগাদ মারাঠারা মুঘল সেনাবাহিনীর বিপক্ষে সফলতা লাভ করে এবং দক্ষিণাত্য থেকে বাংলা পর্যন্ত বেশ কিছু মুঘল প্রদেশে বিজয়ী হয়। সাম্রাজ্যের প্রশাসনিক ও অর্থনৈতিক প্রক্রিয়ার দুর্বলতার কারণে অভ্যন্তরীণ অসন্তোষ সৃষ্টি হয় যার ফলে বিভিন্ন প্রদেশ কার্যত স্বাধীন হয়ে পড়ে। বড় বড় শিল্পী, সাহিত্যিক, বিজ্ঞানী, সেনানায়ক, ধর্মপ্রবর্তক সকলেই ছিলেন অধ্যবসায়ী। তাঁরা বারবার ব্যর্থ হয়েও অক্লান্ত পরিশ্রম করে অসীম ধৈর্য সহকারে নিজ নিজ আদর্শের পথে অগ্রসর হয়েছেন।ছাত্রজীবনে অধ্যবসায়: ছাত্রজীবনে অধ্যবসায়ের বিকল্প নেই। মানুষের জীবন নির্মাণের প্রস্তুতিপর্ব ছাত্রজীবন। তাই যে ছাত্র। যত বেশি অধ্যবসায়ী সে তত সুন্দর জীবনের অধিকারী হয়। যার ছাত্রজীবন আলস্যে পরিপূর্ণ তার পক্ষে কোনােকালেই নন্দিত জীবনের তৃপ্তিভােগ করা সম্ভব নয়। ছাত্রজীবনের প্রস্তুতিই জীবনের পরিপূর্ণতাকে নির্ধারণ করে। তাই গৌরবময় জীবনের অধিকারী হতে হলে ছাত্রজীবনে অধ্যবসায়ী হতে হবে ।ব্যক্তি ও জাতীয় জীবনে অধ্যবসায়:."
essay = document1

# Split the essay into lines
lines = essay.splitlines()

# Process each line as needed
processed_lines = []
for line in lines:
    # Perform your desired changes on each line
    # print(line)
    processed_line = cleaning(line)
    # print(processed_line)
    processed_lines.append(processed_line)

# Join the processed lines back into an essay
processed_essay = '\n'.join(processed_lines)

# Update the df column with the processed essay
document1 = processed_essay
# print(document1)
f=check_plagiarism(document1)

if f==1:
  print("Plagiarism Detected")
else :
  print("No Plagiarism Found")
# Out:
# [[0.84013383]]
# অধ্যবসায়
# Plagiarism Detected
# Plagiarism Detected

# %%
test= pd.read_excel("/content/drive/MyDrive/L4/CSE 404/bangla_essay_plagiarism_test_dataset.xlsx")
test
# Out:
#                                             name  \
# 0                                      অধ্যবসায়
# 1                                      অধ্যবসায়
# 2                                     অধ্যবসায়
# 3                                      অধ্যবসায়
# 4                        রোকেয়া সাখাওয়াত হোসেন
# 5                                            গরু
# 6                        বাংলাদেশের পর্যটন শিল্প
# 7                                বাংলাদেশের উৎসব
# 8                                জগদীশচন্দ্র বসু
# 9                          লঞ্চ ভ্রমণের অভিজ্ঞতা
# 10                     মাদকাসক্তি ও তার প্রতিকার
# 11            মাদকাসক্তির পরিণাম ও প্রতিকার রচনা
# 12                        দৈনন্দিন জীবনে বিজ্ঞান
# 13                        দৈনন্দিন জীবনে বিজ্ঞান
# 14                         লঞ্চ ভ্রমণের অভিজ্ঞতা
# 15                                কৃষি উদ্যোক্তা
# 16                   অদম্য অগ্রযাত্রায় বাংলাদেশ
# 17                                  আমাদের গ্রাম
# ...

# %%
import numpy as np
tp = 0
tn = 0
fp = 0
fn = 0
cnt = 0
for index, row in test.iterrows():
    # if index==6 :
    #   continue
    essay = row['essay']
    if isinstance(essay, float):
        continue  # Skip this iteration if the essay is a float

    lines = essay.splitlines()

    # Process each line as needed
    processed_lines = []
    for line in lines:
        # Perform your desired changes on each line
        processed_line = cleaning(line)
        processed_lines.append(processed_line)

    # Join the processed lines back into an essay
    processed_essay = '\n'.join(processed_lines)

    # Update the df column with the processed essay
    document1 = processed_essay
    # print(index)
    # print(test['name'][index] + "\n")

    if pd.isna(document1):
        print("Skipping plagiarism check: NaN value encountered")
    else:
        if isinstance(document1, bytes):
            document1 = document1.decode('utf-8')  # Convert bytes to unicode string if necessary

        f = check_plagiarism(document1)
        if f==1 and test['plagiarism'][index]==1:
          tp += 1
        if f==0 and test['plagiarism'][index]==0 :
          tn += 1
        if f==1 and test['plagiarism'][index]==0 :
          fp += 1
        if f==0 and test['plagiarism'][index]==1 :
          fn += 1

        print(test['name'][index])
        if f == 1:
            print("Plagiarism Detected")
            # if test['plagiarism'][index]==0 :
            #   print(test['name'][index])
        else:
            print("No Plagiarism Found")
            # if test['plagiarism'][index]==1 :
            #   print(test['name'][index]+" Rev\n")

    cnt += 1
    print("\n")
# Out:
# [[1.]]
# অধ্যবসায়
# Plagiarism Detected
# অধ্যবসায়
# Plagiarism Detected
#
#
# [[0.90655494]]
# অধ্যবসায়
# Plagiarism Detected
#  অধ্যবসায়
# Plagiarism Detected
#
#
# [[0.92327734]]
# অধ্যবসায়
# Plagiarism Detected
# অধ্যবসায়
# Plagiarism Detected
#
#
# [[0.90991928]]
# অধ্যবসায়
# Plagiarism Detected
# অধ্যবসায়
# Plagiarism Detected
#
#
# [[1.]]
# রোকেয়া সাখাওয়াত হোসেন
# Plagiarism Detected
# রোকেয়া সাখাওয়াত হোসেন
# Plagiarism Detected
#
#
# গরু
# No Plagiarism Found
#
#
# [[0.86891598]]
# বাংলাদেশের পর্যটনশিল্প : সমস্যা ও সম্ভাবনা
# Plagiarism Detected
# বাংলাদেশের পর্যটন শিল্প
# Plagiarism Detected
#
#
# বাংলাদেশের উৎসব
# No Plagiarism Found
#
#
# জগদীশচন্দ্র বসু
# No Plagiarism Found
#
#
# লঞ্চ ভ্রমণের অভিজ্ঞতা
# No Plagiarism Found
#
#
# [[0.87087231]]
# মাদকাসক্তি ও এর প্রতিকার
# Plagiarism Detected
# মাদকাসক্তি ও তার প্রতিকার
# Plagiarism Detected
#
#
# [[0.93472058]]
# মাদকাসক্তি ও এর প্রতিকার
# Plagiarism Detected
# মাদকাসক্তির পরিণাম ও প্রতিকার রচনা
# ...
